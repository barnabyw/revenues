# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\barna\OneDrive\Documents\data\nem\nemosis_raw\price_2024_25.csv")

# %%
df["SETTLEMENTDATE"] = pd.to_datetime(df["SETTLEMENTDATE"])
df['Time'] = df['SETTLEMENTDATE'].dt.time
df['Year'] = df['SETTLEMENTDATE'].dt.year
df['Quarter'] = df['SETTLEMENTDATE'].dt.quarter

# %%
df.to_csv(r"C:\Users\barna\OneDrive\Documents\data\nem\processed\rrp.csv", index=False)
